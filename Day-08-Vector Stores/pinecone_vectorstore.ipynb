# %%
# !pip install langchain chromadb openai langchain_openai langchain_community tiktoken pypdf langchain-chroma langchain-pinecone

# %%
import os
os.environ["OPENAI_API_KEY"] = ""
os.environ["PINECONE_API_KEY"] = ""

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_pinecone import PineconeVectorStore

# %%
from langchain_core.documents import Document

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1,doc2,doc3,doc4,doc5]

# %%
# Create Vector store

vector_store = PineconeVectorStore(
    embedding=OpenAIEmbeddings(),
    index_name="trial-index"
)

# %%
# add documents
vector_store.add_documents(docs)
# Out:
# ['b13dc19c-c679-486f-8b58-3900c3bd1e60',
#  '83f76ee1-2816-48bd-ae99-56f23c279154',
#  'b94cc3c1-96d7-4923-a7de-58a2e3cc599b',
#  'ba7c27e4-096b-436a-ab70-53366e7458d8',
#  'cbc6cb9c-ec9c-4e1a-9c9b-69fafe292abb']

# %%
# view documents
vector_store.similarity_search(query='',k=10)
# Out:
# [Document(id='0a14ce5a-6267-4f2c-b878-ea88cfd85dbe', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(id='ba7c27e4-096b-436a-ab70-53366e7458d8', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(id='83f76ee1-2816-48bd-ae99-56f23c279154', metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
# ...

# %%
# delete documetns
vector_store.delete(ids=['b13dc19c-c679-486f-8b58-3900c3bd1e60',
 '83f76ee1-2816-48bd-ae99-56f23c279154',
 'b94cc3c1-96d7-4923-a7de-58a2e3cc599b',
 'ba7c27e4-096b-436a-ab70-53366e7458d8',
 'cbc6cb9c-ec9c-4e1a-9c9b-69fafe292abb'])

# %%
vector_store.similarity_search(query='',k=10)
# Out:
# [Document(id='0a14ce5a-6267-4f2c-b878-ea88cfd85dbe', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(id='d03cdb15-40e3-4346-a6de-77135f223e84', metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#  Document(id='f31c2669-fb0c-46f3-9c92-7c33a675a456', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
# ...

# %%
# Search documents
vector_store.similarity_search(
    query='who is bowler?',
    k=2
)
# Out:
# [Document(id='0a14ce5a-6267-4f2c-b878-ea88cfd85dbe', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(id='5bfa1a45-9d50-4fb7-bffe-5acd5faf2d35', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.')]

# %%
# search with scores
vector_store.similarity_search_with_score(
      query='who is bowler?',
    k=2
)
# Out:
# [(Document(id='0a14ce5a-6267-4f2c-b878-ea88cfd85dbe', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.793518126),
#  (Document(id='5bfa1a45-9d50-4fb7-bffe-5acd5faf2d35', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.741394043)]

# %%
# metadata filtering
vector_store.similarity_search(
    query="who is bowler?",
    k=2,
    filter={"team":'Chennai Super Kings'}
)
# Out:
# [Document(id='5bfa1a45-9d50-4fb7-bffe-5acd5faf2d35', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#  Document(id='f31c2669-fb0c-46f3-9c92-7c33a675a456', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.')]

# %%
from langchain_core import documents
# update document

updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)

vector_store.add_documents(ids=['a59e9fdb-0a03-4ad1-b528-d0afa67dcbce'],documents=[updated_doc1])
# Out:
# ['a59e9fdb-0a03-4ad1-b528-d0afa67dcbce']

# %%
pinecone_index = vector_store.get_pinecone_index(index_name='trial-index')
result = pinecone_index.fetch(ids=['a59e9fdb-0a03-4ad1-b528-d0afa67dcbce'])

# %%
vector_data = result.vectors['a59e9fdb-0a03-4ad1-b528-d0afa67dcbce']
vector_data['metadata']
# Out:
# {'team': 'Royal Challengers Bangalore',
#  'text': "Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket."}
